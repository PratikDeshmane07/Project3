# %%
# Import dependencies
import pandas as pd
import sqlite3
from sqlalchemy import create_engine

# %%
restaurant_df=pd.read_csv('./data/kayak_data_v04-2.csv')

restaurant_df.head()
# Out:
#                        name            locality                cuisine  \
# 0  Broadstone Bar & Kitchen  Financial District               American
# 1       Stone Street Tavern  Financial District               American
# 2          Industry Kitchen  Financial District               American
# 3           The Ketch - NYC  Financial District  Contemporary American
# 4   The Tuck Room- New York  Financial District            Unspecified
#
#   price_per_person  overall_rating  food  service  ambiance  reviews  \
# 0                $             4.2   4.1      4.1       4.1      268
# 1                $             4.5   4.4      4.5       4.2       75
# 2                $             4.5   4.3      4.4       4.5      440
# 3                $             4.0   3.9      3.9       3.8      534
# 4                $             4.2   4.1      4.1       4.4     1163
#
#       noise    dining_style   latitude  longitude  \
# 0  Moderate   Casual Dining  40.704115 -74.011729
# 1  Moderate   Casual Dining  40.704278 -74.010273
# 2  Moderate   Casual Dining  40.704921 -74.004874
# 3  Moderate  Casual Elegant  40.706306 -74.007466
# 4  Moderate  Casual Elegant  40.706629 -74.003141
#
#                                                  url
# 0  https://www.kayak.com/New-York-Restaurants-Bro...
# 1  https://www.kayak.com/New-York-Restaurants-Sto...
# 2  https://www.kayak.com/New-York-Restaurants-Ind...
# 3  https://www.kayak.com/New-York-Restaurants-The...
# 4  https://www.kayak.com/New-York-Restaurants-The...

# %%
restaurant_df=restaurant_df.reset_index()
restaurant_df=restaurant_df.reset_index(drop=True).rename(columns={'index':'restaurant_id'})
restaurant_df.head()
# Out:
#    restaurant_id                      name            locality  \
# 0              0  Broadstone Bar & Kitchen  Financial District
# 1              1       Stone Street Tavern  Financial District
# 2              2          Industry Kitchen  Financial District
# 3              3           The Ketch - NYC  Financial District
# 4              4   The Tuck Room- New York  Financial District
#
#                  cuisine price_per_person  overall_rating  food  service  \
# 0               American                $             4.2   4.1      4.1
# 1               American                $             4.5   4.4      4.5
# 2               American                $             4.5   4.3      4.4
# 3  Contemporary American                $             4.0   3.9      3.9
# 4            Unspecified                $             4.2   4.1      4.1
#
#    ambiance  reviews     noise    dining_style   latitude  longitude  \
# 0       4.1      268  Moderate   Casual Dining  40.704115 -74.011729
# 1       4.2       75  Moderate   Casual Dining  40.704278 -74.010273
# 2       4.5      440  Moderate   Casual Dining  40.704921 -74.004874
# 3       3.8      534  Moderate  Casual Elegant  40.706306 -74.007466
# 4       4.4     1163  Moderate  Casual Elegant  40.706629 -74.003141
#
#                                                  url
# 0  https://www.kayak.com/New-York-Restaurants-Bro...
# 1  https://www.kayak.com/New-York-Restaurants-Sto...
# 2  https://www.kayak.com/New-York-Restaurants-Ind...
# 3  https://www.kayak.com/New-York-Restaurants-The...
# 4  https://www.kayak.com/New-York-Restaurants-The...

# %%
connection=sqlite3.connect('./data/kayak_data.sqlite')

# %%
restaurant_df.to_sql('restaurants',connection,if_exists='replace',index=False, dtype={'restaurant_id': 'INTEGER PRIMARY KEY AUTOINCREMENT'})
# Out:
# 711

# %%
connection.close()
