# %%
# Import dependencies
import pandas as pd
import sqlite3
from sqlalchemy import create_engine

# %%
restaurant_df=pd.read_csv('./data/kayak_data_v02.csv')

restaurant_df.head()
# Out:
#                                   name      locality                cuisine  \
# 0             Le Midi Bar & Restaurant     Manhattan                 French
# 1                          Malai Marke  East Village                 Indian
# 2            The Flatiron Room - Nomad       Midtown               American
# 3  Bocca Di Bacco (Chelsea - 20th St.)       Chelsea                Italian
# 4                            Banc Cafe       Midtown  Contemporary American
#
#   price_per_person  overall_rating  food  service  ambiance  reviews  \
# 0       $31 to $50             4.5   4.5      4.5       4.3    182.0
# 1    $30 and under             4.4   4.6      4.3       3.9     26.0
# 2       $31 to $50             4.5   4.2      4.4       4.8    312.0
# 3    $30 and under             4.4   4.5      4.4       4.4    150.0
# 4    $30 and under             4.6   4.4      4.4       4.4   2814.0
#
#       noise    dining_style   latitude   longitude
# 0  Moderate   Casual Dining        NaN         NaN
# 1  Moderate   Casual Dining        NaN         NaN
# 2  Moderate  Casual Elegant        NaN         NaN
# 3  Moderate   Casual Dining        NaN         NaN
# 4  Moderate   Casual Dining -37.813402  144.966343

# %%
restaurant_df=restaurant_df.reset_index()
restaurant_df=restaurant_df.reset_index(drop=True).rename(columns={'index':'restaurant_id'})
restaurant_df.head()
# Out:
#    restaurant_id                                 name      locality  \
# 0              0             Le Midi Bar & Restaurant     Manhattan
# 1              1                          Malai Marke  East Village
# 2              2            The Flatiron Room - Nomad       Midtown
# 3              3  Bocca Di Bacco (Chelsea - 20th St.)       Chelsea
# 4              4                            Banc Cafe       Midtown
#
#                  cuisine price_per_person  overall_rating  food  service  \
# 0                 French       $31 to $50             4.5   4.5      4.5
# 1                 Indian    $30 and under             4.4   4.6      4.3
# 2               American       $31 to $50             4.5   4.2      4.4
# 3                Italian    $30 and under             4.4   4.5      4.4
# 4  Contemporary American    $30 and under             4.6   4.4      4.4
#
#    ambiance  reviews     noise    dining_style   latitude   longitude
# 0       4.3    182.0  Moderate   Casual Dining        NaN         NaN
# 1       3.9     26.0  Moderate   Casual Dining        NaN         NaN
# 2       4.8    312.0  Moderate  Casual Elegant        NaN         NaN
# 3       4.4    150.0  Moderate   Casual Dining        NaN         NaN
# 4       4.4   2814.0  Moderate   Casual Dining -37.813402  144.966343

# %%
connection=sqlite3.connect('./data/kayak_data.sqlite')

# %%
restaurant_df.to_sql('restaurants',connection,if_exists='replace',index=False, dtype={'restaurant_id': 'INTEGER PRIMARY KEY AUTOINCREMENT'})
# Out:
# 943

# %%
connection.close()
