# %%
# Dependencies
import requests
import json
from pathlib import Path
import pandas as pd
from geopy.geocoders import Nominatim

# %%
# Define the path to your JSON file
json_file = '../yelp_3/yelp_dataset/yelp_academic_dataset_business.json'

# %%
# Read the JSON file into a DataFrame
with open(json_file, 'r', encoding='utf-8') as file:
    data = [json.loads(line) for line in file]

df = pd.DataFrame(data)

# %%
# View the first 5 rows
df.head(5)
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# ...

# %%
# List out the column titles
column_titles = df.columns
print(column_titles)
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours'],
#       dtype='object')

# %%
# Filter the DataFrame to keep only rows with 'NY' in the 'state' column
df_ny = df[df['state'] == 'NY']

# Display the first 5 rows of the filtered DataFrame
print(df_ny.head(5))
# Out:
# Empty DataFrame
# Columns: [business_id, name, address, city, state, postal_code, latitude, longitude, stars, review_count, is_open, attributes, categories, hours]
# Index: []

# %%
# Get the count of each unique value in the 'state' column
state_counts = df['state'].value_counts()

# Print out the unique values and their counts
for state, count in state_counts.items():
    print(f'State: {state}, Count: {count}')
# Out:
# State: PA, Count: 34039
# State: FL, Count: 26330
# State: TN, Count: 12056
# State: IN, Count: 11247
# State: MO, Count: 10913
# State: LA, Count: 9924
# State: AZ, Count: 9912
# State: NJ, Count: 8536
# State: NV, Count: 7715
# State: AB, Count: 5573
# State: CA, Count: 5203
# State: ID, Count: 4467
# State: DE, Count: 2265
# State: IL, Count: 2145
# State: TX, Count: 4
# State: CO, Count: 3
# State: WA, Count: 2
# State: HI, Count: 2
# State: MA, Count: 2
# State: NC, Count: 1
# State: UT, Count: 1
# State: MT, Count: 1
# State: MI, Count: 1
# State: SD, Count: 1
# State: XMS, Count: 1
# State: VI, Count: 1
# State: VT, Count: 1

# %%
# Filter the DataFrame to keep only rows with 'NY' in the 'state' column
df_ny = df_sorted[df_sorted['state'] == 'NY']

# Display the first 10 rows of the filtered DataFrame
df_ny.head(10)
# Out:
# Empty DataFrame
# Columns: [business_id, name, address, city, state, postal_code, latitude, longitude, stars, review_count, is_open, attributes, categories, hours]
# Index: []

# %%
# Sort the DataFrame by the "STATE" column in ascending order
df_sorted = df.sort_values(by='state', ascending=True)

# Display the first 10 rows of the sorted DataFrame
df_sorted.head(5)
# Out:
#                    business_id                         name  \
# 96221   t2Rhq5ubtKYJB1oqWi_pcw                McBain Camera
# 127395  xv2optDghfbxGDhTSCvxEA        Whitemud World Health
# 30415   823OhurSJe7SKhFvd9u0uQ          Devaney's Irish Pub
# 71646   mY7DKQ6qQYr_V21TWmspOA       Milestones Restaurants
# 71635   73uFR4QuDuH9VD1oehtOQQ  Summerside Pizza and Donair
# 127428  YHN77g2zWsEN1F_q9W_WdQ               Cha Island Tea
# 71602   2whW4Ko3ZvtPtLvlrSDsSg           Apple Box Boutique
# 127453  u-2a-1lUIriHWcsdOZTbmw           Sobeys Urban Fresh
# 127471  CMGjAu34wZIW6wrLH8fIZg                Candy Bouquet
# 127485  q9rKHxk39vde6IJmOBqQ5g                The Face Shop
#
#                                address       city state postal_code  \
# 96221              10805 107 Avenue NW   Edmonton    AB     T5H 0W9
# 127395               4219 99 Street NW   Edmonton    AB     T6E 5V7
# 30415               11113 87 Avenue NW   Edmonton    AB     T6G 0X8
# ...

# %%
df_sorted.tail(5)
# Out:
#                    business_id  \
# 95091   oTRrNy5VIaTw7MKEvxZl7A
# 34661   Zo2tRIvtAfoENtbw2USoYg
# 97813   kEjAs-w4dN9W1n6jE7Tivg
# 32536   qw_eRqiGeYwsbTfkpd_Pqg
# 32345   f-S2Y0OO00cQjo8yj3upKg
# 135715  QQXwvLlbMtnAgjY8YKEzuA
# 144012  g0fYqQRRKmYIfChE4jMLsg
# 29606   qbh_Xg-wfgk_qINdyApMag
# 10948   kNK3tjrKa6e_Tf9c9WWehA
# 98685   IvQs2hhXKZ4NgZhVZ5jjjQ
#
#                                                   name  \
# 95091                                 Wildlife Wonders
# 34661                                   2400 Briarwest
# 97813   Residences at Glenview Reserve Apartment Homes
# 32536                             Southern Luxe Beauty
# 32345                                    Find Your Zen
# 135715                                    The Moorings
# 144012                               All Service Citgo
# 29606                     Valvoline Instant Oil Change
# 10948                                      Suave Nails
# 98685                           Pumpernickles Catering
#
# ...

# %%
# Filter the DataFrame to keep only rows with 'NY' in the 'state' column
df_ny = df_sorted[df_sorted['state'] == 'NY']

# Display the first 10 rows of the filtered DataFrame
df_ny.head(10)
# Out:
# Empty DataFrame
# Columns: [business_id, name, address, city, state, postal_code, latitude, longitude, stars, review_count, is_open, attributes, categories, hours]
# Index: []

# %%
# Filter the DataFrame to keep only rows with 'NY' in the 'state' column
df_tx = df_sorted[df_sorted['state'] == 'TX']

# Display the first 10 rows of the filtered DataFrame
df_ny.head(10)

# %%
# Define the path for the CSV output file
csv_file = 'yelp_academic_dataset_business.csv'

# Export the DataFrame to a CSV file
df_sorted.to_csv(csv_file, index=False)

# %%
######################################################################################################
